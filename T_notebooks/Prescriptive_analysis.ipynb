# %%
""" Prescriptive analysis
This Notebook contains the Prescriptive analysis data 
Here the data can be accessed ,
Can be used for plotting,
And further analysis

Author: Vishank
Created: 11 December 2025
"""
# Out:
# ' Prescriptive analysis\nThis Notebook contains the Prescriptive analysis data \nHere the data can be accessed ,\nCan be used for plotting,\nAnd further analysis\n\nAuthor: Vishank\nCreated: 11 December 2025\n'

# %%
import sys
import os

project_root = os.path.abspath("..")
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
#importing packages
import pandas as pd 
from src.analytics import SalesAnalytics

# %%
#variable to access the class from analytics.py
analytics=SalesAnalytics()
# Out:
# Connected to database at: c:\Users\ASUS\Documents\ecommerce-sales-intelligence\database\ecommerce.db

# %%
#Products to discount (low sales + low profit)
print("Finding Products which Should Have Discounts ")
Discounted_products = analytics.Products_to_Discount()
print("Products which Should Have Discounts Are:")
print(Discounted_products)
# Out:
# Finding Products which Should Have Discounts
# Products which Should Have Discounts Are:
# Empty DataFrame
# Columns: [product, sales, profit]
# Index: []

# %%
#Products to Promote (High sales + High profit)
print("Finding Products which Should be Promoted ")
Promoted_products = analytics.Products_to_promote()
print("Products which Should be Promoted Are:")
print(Promoted_products)
# Out:
# Finding Products which Should be Promoted
# Products which Should be Promoted Are:
# Empty DataFrame
# Columns: [product, sales, profit]
# Index: []

# %%
#Customers to target for loyalty program
print("Finding Customers to target for loyalty program")
Loyal_custommers = analytics.Loyal_customers()
print(" Customers to target for loyalty program Are:")
print(Loyal_custommers)
# Out:
# Finding Customers to target for loyalty program
#  Customers to target for loyalty program Are:
# Empty DataFrame
# Columns: [customer_id, customer_name, total_sales, total_orders]
# Index: []

# %%
#Customers at risk of churn(leaving the services)
print("Finding Customers at risk of churn(leaving the services)")
Churn_custommers = analytics.Churning_customers()
print(" Customers at risk of churn(leaving the services) Are:")
print(Churn_custommers)
# Out:
# Finding Customers at risk of churn(leaving the services)
#  Customers at risk of churn(leaving the services) Are:
#       customer_id     customer_name  last_order
# 0      AK-0031597         Wyatt Pak  2015-01-01
# 1      AL-0050367   Whitaker Nazzal  2015-01-01
# 2      AN-0010317      Leon Sissman  2015-01-01
# 3      AN-0012354   Bradford Noonan  2015-01-01
# 4      AN-0019762  Williams Abelman  2015-01-01
# ...           ...               ...         ...
# 51285   TZ-003708       Casey Mautz  2015-12-31
# 51286  TZ-0045856   Prince Schwartz  2015-12-31
# 51287  UM-0030535     Chase Mitchum  2015-12-31
# 51288  UN-0024630     Bennett Braun  2015-12-31
# 51289  YE-0040682   Carlson Flentye  2015-12-31
#
# [51290 rows x 3 columns]

# %%
#Cities requiring logistics improvement
print("Finding Cities requiring logistics improvement")
Improve_cities = analytics.Cities_improvement()
print("Cities requiring logistics improvement Are:")
print(Improve_cities)
# Out:
# Finding Cities requiring logistics improvement
# Cities requiring logistics improvement Are:
#              city  avg_delivery_delay
# 0         Xuanhua                10.0
# 1         Xingtai                10.0
# 2            Sète                10.0
# 3       Stadtlohn                10.0
# 4     Southampton                10.0
# ...           ...                 ...
# 3631    Arapongas                 1.0
# 3632    Annemasse                 1.0
# 3633         Anjo                 1.0
# 3634       Akhmim                 1.0
# 3635   Abbotsford                 1.0
#
# [3636 rows x 2 columns]

# %%
#Ship modes requiring optimization
print("Finding Ship modes requiring optimization")
Improve_shipping = analytics.Optimized_shipping()
print("Ship modes requiring optimization Are:")
print(Improve_shipping)
# Out:
# Finding Ship modes requiring optimization
# Ship modes requiring optimization Are:
#         ship_mode  avg_delivery_days  total_cost
# 0     First Class           5.542239     48427.9
# 1  Standard Class           5.491503    248366.0
# 2    Second Class           5.454845     58793.4
# 3        Same Day           1.000000     17435.8
