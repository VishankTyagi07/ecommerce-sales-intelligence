# %%
""" Predictive analysis
This Notebook contains the Predictive analysis data 
Here the data can be accessed ,
Can be used for plotting,
And further analysis

Author: Vishank
Created: 11 December 2025
"""
# Out:
# ' Predictive analysis\nThis Notebook contains the Predictive analysis data \nHere the data can be accessed ,\nCan be used for plotting,\nAnd further analysis\n\nAuthor: Vishank\nCreated: 11 December 2025\n'

# %%
import sys
import os

project_root = os.path.abspath("..")
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
#importing packages
import pandas as pd 
from src.analytics import SalesAnalytics

# %%
#variable to access the class from analytics.py
analytics=SalesAnalytics()
# Out:
# Connected to database at: c:\Users\ASUS\Documents\ecommerce-sales-intelligence\database\ecommerce.db

# %%
#RFM (Recency, Frequency, Monetary) signals
print("Finding RFM (Recency, Frequency, Monetary) Signals ")
RFM_signals = analytics.RFM_signals()
print(" RFM (Recency, Frequency, Monetary) Signals Are:")
print("Recency Signals Are:\n",RFM_signals['Recency'])
print("Frequency Signals Are:\n",RFM_signals['Frequency'])
print("Monetary Signals Are:\n",RFM_signals['Monetary'])
# Out:
# Finding RFM (Recency, Frequency, Monetary) Signals
#  RFM (Recency, Frequency, Monetary) Signals Are:
# Recency Signals Are:
#        customer_id    customer_name last_order_date
# 0      AB-0010767  Mcintyre Yedwab      2015-12-10
# 1      AB-0010840  Mcintyre Yedwab      2015-11-22
# 2      AB-0011247   Whitney Yedwab      2015-11-10
# 3      AB-0011531  Mcintyre Yedwab      2015-08-23
# 4      AB-0011875   Whitney Yedwab      2015-10-16
# ...           ...              ...             ...
# 51285   ZO-006146    Fox D'Ascenzo      2015-12-25
# 51286   ZO-006598    Fox D'Ascenzo      2015-07-13
# 51287   ZO-007407    Fox D'Ascenzo      2015-08-10
# 51288   ZO-008768    Fox D'Ascenzo      2015-01-21
# 51289    ZO-00914    Fox D'Ascenzo      2015-04-07
#
# [51290 rows x 3 columns]
# Frequency Signals Are:
#        customer_id  total_orders
# 0      AB-0010767             1
# 1      AB-0010840             1
# 2      AB-0011247             1
# 3      AB-0011531             1
# ...

# %%
#Monthly sales for detecting seasonal demands
print("Finding Top Monthly Sales for Analysing Seasonal Demands ")
Seasonal_demands = analytics.Seasonal_demands()
print("Top Monthly Sales for Analysing Seasonal Demands Are:")
print(Seasonal_demands)
# Out:
# Finding Top Monthly Sales for Analysing Seasonal Demands
# Top Monthly Sales for Analysing Seasonal Demands Are:
#        months  orders   sales
# 0    December    4429  693073
# 1     October    4380  689055
# 2       March    4412  686681
# 3        July    4445  685152
# 4     January    4365  676313
# 5         May    4293  672547
# 6      August    4298  670788
# 7        June    4211  664560
# 8       April    4176  659404
# 9   September    4197  658844
# 10   November    4207  656663
# 11   February    3877  610240

# %%
#Products Performance per month
print("Finding Products Performance Trends")
Products_performance = analytics.Product_performance()
print("The Products performance Trend per Month Are:")
print(Products_performance)
# Out:
# Finding Products Performance Trends
# The Products performance Trend per Month Are:
#           product    month  monthly_sales
# 0    Apple Laptop  2015-01           5000
# 1    Apple Laptop  2015-02           3500
# 2    Apple Laptop  2015-03           2750
# 3    Apple Laptop  2015-04           4000
# 4    Apple Laptop  2015-05           5500
# ..            ...      ...            ...
# 499         Watch  2015-08           2600
# 500         Watch  2015-09           2392
# 501         Watch  2015-10           2600
# 502         Watch  2015-11           1456
# 503         Watch  2015-12           1352
#
# [504 rows x 3 columns]

# %%
#Monthly sales for forecasting
print("Finding Monthly Sales For Forecasting Future Sales")
Monthly_sales_forecasting = analytics.Monthly_sales_forecasting()
print("Finding Monthly Sales For Forecasting Future Sales Are:")
print(Monthly_sales_forecasting)
# Out:
# Finding Monthly Sales For Forecasting Future Sales
# Finding Monthly Sales For Forecasting Future Sales Are:
#       month  monthly_sales
# 0   2015-01         676313
# 1   2015-02         610240
# 2   2015-03         686681
# 3   2015-04         659404
# 4   2015-05         672547
# 5   2015-06         664560
# 6   2015-07         685152
# 7   2015-08         670788
# 8   2015-09         658844
# 9   2015-10         689055
# 10  2015-11         656663
# 11  2015-12         693073

# %%
#High risk orders(low profit or high aging)
print("Finding High Risk Orders(Products with Low Profit Or High aging) ")
High_risk_orders = analytics.High_risk_orders()
print(" High Risk Orders(Products with Low Profit Or High aging) Are:")
print("Low Profit Products Are:\n",High_risk_orders['L_Profit'])
print("High aging Prodcuts Are:\n",High_risk_orders['H_Aging'])
# Out:
# Finding High Risk Orders(Products with Low Profit Or High aging)
#  High Risk Orders(Products with Low Profit Or High aging) Are:
# Low Profit Products Are:
#  Empty DataFrame
# Columns: [order_id, order_date, ship_date, aging, ship_mode, product_category, product, sales, quantity, discount, profit, shipping_cost, order_priority, customer_id, customer_name, segment, city, state, country, region, months]
# Index: []
#
# [0 rows x 21 columns]
# High aging Prodcuts Are:
#        order_id  order_date   ship_date  aging    ship_mode  \
# 0  AU-2015-440  2015-06-01  2015-06-11   10.5  First Class
#
#      product_category          product  sales  quantity  discount  ...  \
# 0  Auto & Accessories  Car Seat Covers    114         2      0.04  ...
#
#    shipping_cost  order_priority customer_id customer_name      segment  \
# 0            2.5            High    ER-00440   Diaz Bühler  Home Office
#
#                    city      state country region months
# ...
